# %%
import nltk
import pandas as pd
from bs4 import BeautifulSoup
import requests
import re

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\victo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
#Data Extraction
url = 'https://www.planalto.gov.br/ccivil_03/constituicao/constituicaocompilado.htm'

headers = {"User-Agent":'Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/59.0.3071.115 Safari/537.36'}

page = requests.get(url, headers=headers, verify=False)

html = BeautifulSoup(page.text, 'html.parser')
# Out:
# c:\users\victo\.repos\infolaw_proje\.venv\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.planalto.gov.br'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
titulolegal = []
for i in html:
    for l in i:
        titulolegal = [p.get_text() for p in l]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [5], in <cell line: 2>()
#       2 for i in html:
#       3     for l in i:
# ----> 4         titulolegal = [p.get_text() for p in l]
#
# Input In [5], in <listcomp>(.0)
#       2 for i in html:
#       3     for l in i:
# ----> 4         titulolegal = [p.get_text() for p in l]
#
# AttributeError: 'str' object has no attribute 'get_text'

# %%
titulo = html.find_all('p')
titulo2 = str([p.get_text() for p in titulo])
daoora = re.sub(r'\\n', '', titulo2, count=0)
daoora2 = re.sub(r'\\xa0', '', daoora, count=0)
daoora3 = re.sub(r'\\r', '', daoora2, count=0)
daoora4 = re.sub(r'\\t', '', daoora3, count=0)


print(daoora4)
# Out:
# ['', 'Presidência    da RepúblicaCasa CivilSubchefia para Assuntos Jurídicos', 'CONSTITUIÇÃO DA REPÚBLICA FEDERATIVA DO BRASIL    DE 1988', 'Vide Emenda Constitucional nº 91, de 2016Vide Emenda Constitucional nº 106, de 2020Vide Emenda Constitucional nº 107, de 2020', 'Vide Emenda Constitucional nº 106, de 2020Vide Emenda Constitucional nº 107, de 2020', 'Vide Emenda Constitucional nº 107, de 2020', 'Emendas Constitucionais', 'Emendas Constitucionais de Revisão', 'Ato das Disposições    Constitucionais Transitórias', 'Atos decorrentes do disposto no   § 3º do art. 5º', 'ÍNDICE TEMÁTICO', 'PREÂMBULO', 'Nós, representantes do povo brasileiro, reunidos em Assembléia Nacional Constituintepara instituir um Estado Democrático, destinado a assegurar o exercício dos direitossociais e individuais, a liberdade, a segurança, o bem-estar, o desenvolvimento, aigualdade e a justiça como valores supremos de uma sociedade fraterna, pluralista e sempreconceitos, fundada na harmonia social e compromet
# ...

# %%
legal = html.find_all('p', attrs={'align':"JUSTIFY"})
legal2 = str([p.get_text() for p in legal])
daoora = re.sub(r'\\n', '', legal2, count=0)
daoora2 = re.sub(r'\\xa0', '', daoora, count=0)
daoora3 = re.sub(r'\\r', '', daoora2, count=0)
#legal3 = p.split('\r') for p in legal2
print(daoora3)
#legal = [list(filter(None ,p.get_text().split('\n')))for p in specif]
# Out:
# ['Nós, representantes do povo brasileiro, reunidos em Assembléia Nacional Constituintepara instituir um Estado Democrático, destinado a assegurar o exercício dos direitossociais e individuais, a liberdade, a segurança, o bem-estar, o desenvolvimento, aigualdade e a justiça como valores supremos de uma sociedade fraterna, pluralista e sempreconceitos, fundada na harmonia social e comprometida, na ordem interna e internacional,com a solução pacífica das controvérsias, promulgamos, sob a proteção de Deus, aseguinte CONSTITUIÇÃO DA REPÚBLICA FEDERATIVA DO BRASIL.', 'Art. 1º A República Federativa do Brasil,formada pela união indissolúvel dos Estados e Municípios e do Distrito Federal,constitui-se em Estado Democrático de Direito e tem como fundamentos:', 'I - a soberania;', 'II - a cidadania', 'III - a dignidade da pessoa humana;', 'IV - os valores sociais do trabalho e da livre iniciativa;          (Vide Lei nº 13.874, de 2019)    ', 'V - o pluralismo político.', 'Parágrafo único. Todo 
# ...

# %%
regex = nltk.tokenize.RegexpTokenizer('\s+', gaps=True)

res = regex.tokenize(text=soup.find('p', attrs={'align':"JUSTIFY"}).get_text())

# %%
df_clean = []
titulos = []
titulo = html.find_all('p')
for p in titulo:
    legal = str([p.get_text()])
    daoora = re.sub(r'\\n', '', legal, count=0)
    daoora2 = re.sub(r'\\xa0', '', daoora, count=0)
    daoora3 = re.sub(r'\\r', '', daoora2, count=0)
    daoora4 = re.sub(r'\\t', '', daoora3, count=0)
    #df_clean.append(daoora4)
    
    #df_clean.append(daoora4)     
    if 'TÍTULO' in daoora4:
        titulos.append(daoora4)
        
    if 'Art.' in daoora4:
        df_clean.append(daoora4)
   
    #for l in titulos:
    print(df_clean)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
if daoora4.index(,0,3).startswith('Art'):
# Out:
# In Memoriam: Alair Ferreira - Antônio
# Farias - Fábio Lucena - Norberto Schwantes - Virgílio Távora.

# %%
print(df_clean)
# Out:
# ["['Art. 1º A República Federativa do Brasil,formada pela união indissolúvel dos Estados e Municípios e do Distrito Federal,constitui-se em Estado Democrático de Direito e tem como fundamentos:']", "['Art. 2º São Poderes da União, independentes e harmônicos entre si, oLegislativo, o Executivo e o Judiciário.']", "['Art. 3º Constituem objetivos fundamentais da República Federativa doBrasil:']", "['Art. 4º A República Federativa do Brasil rege-se nas suas relaçõesinternacionais pelos seguintes princípios:']", "['Art. 5º Todos são iguais perante a lei, semdistinção de qualquer natureza, garantindo-se aos brasileiros e aos estrangeirosresidentes no País a inviolabilidade do direito à vida, à liberdade, à igualdade, àsegurança e à propriedade, nos termos seguintes:']", "['Art. 6º São direitos sociais a educação, a saúde, a alimentação, o trabalho, a moradia, o transporte, o lazer, a segurança, a previdência social, a proteção à maternidade e à infância, a assistência aos desamparados, na 
# ...

# %%
titulol = html.find_all('a', class_='cstf')
lalala = [i.get_text() for i in titulol]

# %%
print(lalala)
# Out:
# ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '\n', '\n', '', '', '', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '', '', '', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '',
# ...
